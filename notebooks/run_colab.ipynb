# %%
# !pip install pytorch-lightning
# Out:
# ...
#      |████████████████████████████████| 582 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 596 kB 33.8 MB/s
# ...
#      |████████████████████████████████| 136 kB 14.4 MB/s
# ...
#      |████████████████████████████████| 408 kB 11.2 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 39.2 MB/s
# ...
#      |████████████████████████████████| 144 kB 49.3 MB/s
# ...
#      |████████████████████████████████| 94 kB 3.2 MB/s
# ...
#      |████████████████████████████████| 271 kB 53.4 MB/s
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !rm -rf /content/MLOps
# !git clone --branch add_modules_ https://github.com/SergeyAnufriev/MLOps.git
# Out:
# Cloning into 'MLOps'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 38 (delta 13), reused 26 (delta 7), pack-reused 0
# Unpacking objects: 100% (38/38), done.

# %%
import sys 
sys.path.append('/content/MLOps')

# %%
from process_data_ import vocab,split_train_,split_valid_,test_dataset,train_iter,collate_batch,num_class
from model_gen import TextClassificationModel
from train_eval import LightningTemplateModel
import pytorch_lightning as pl
# Out:
# 29.5MB [00:00, 88.8MB/s]
# 1.86MB [00:00, 38.5MB/s]

# %%
vocab_size = len(vocab)
emsize = 64
model = TextClassificationModel(vocab_size, emsize, num_class)

# %%
trainer_    = pl.Trainer(max_epochs=10,accelerator="gpu")
model_light = LightningTemplateModel(model,split_train_, split_valid_, test_dataset, collate_batch,64,5)
trainer_.fit(model_light)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True, used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: /content/lightning_logs
# INFO:pytorch_lightning.accelerators.gpu:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name     | Type                    | Params
# -----------------------------------------------------
# 0 | my_model | TextClassificationModel | 6.1 M
# -----------------------------------------------------
# 6.1 M     Trainable params
# 0         Non-trainable params
# 6.1 M     Total params
# 24.529    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# ...
